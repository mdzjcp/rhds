# %%
library(meffonym)
# Out:
# Loading required package: RPMM
#
# Loading required package: cluster
#
# Loading required package: impute
# loading models ...
# Fri Jan 30 14:54:02 2026 Adding model:  wid-smk-distal-epithelial-hyperM
# Fri Jan 30 14:54:02 2026 Adding model:  wid-smk-immune-hypoM
# Fri Jan 30 14:54:02 2026 Adding model:  wid-smk-epithelial-hypoM
# Fri Jan 30 14:54:02 2026 Adding model:  wid-smk-proximal-epithelial-hyperM
# Fri Jan 30 14:54:02 2026 Adding model:  wahl-bmi-european
# Fri Jan 30 14:54:02 2026 Adding model:  wahl-bmi-indian
# Fri Jan 30 14:54:02 2026 Adding model:  wahl-bmi
# Fri Jan 30 14:54:02 2026 Adding model:  gs-cognitive
# Fri Jan 30 14:54:02 2026 Adding model:  patella-lead
# Fri Jan 30 14:54:02 2026 Adding model:  tibia-lead
# Fri Jan 30 14:54:02 2026 Adding model:  cmv
# Fri Jan 30 14:54:02 2026 Adding model:  epismoker-current
# Fri Jan 30 14:54:02 2026 Adding model:  epismoker-former
# Fri Jan 30 14:54:02 2026 Adding model:  epismoker-never
# ...
